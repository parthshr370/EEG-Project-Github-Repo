# %%
import mne

# %%
new = mne.io.read_raw_edf('/home/technoshr370/Downloads/Dataset/ds003751-1.0.6/sub-mit003/eeg/sub-mit003_task-Emotion_eeg_preprocessed.edf')
# Out:
# Extracting EDF parameters from /home/technoshr370/Downloads/Dataset/ds003751-1.0.6/sub-mit003/eeg/sub-mit003_task-Emotion_eeg_preprocessed.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
new.describe()
# Out:
# <RawEDF | sub-mit003_task-Emotion_eeg_preprocessed.edf, 121 x 55750 (223.0 s), ~95 kB, data not loaded>
#  ch  name    type  unit        min         Q1     median         Q3        max
#   0  E1      EEG   µV    -11084.10      -9.30       0.17       9.64    5336.64
#   1  E2      EEG   µV    -11084.10      -6.93      -0.51       6.26    8483.86
#   2  E3      EEG   µV    -11084.10      -6.93      -0.51       5.92    9459.75
#   3  E4      EEG   µV    -11084.10      -4.90      -0.51       4.23    6961.66
#   4  E5      EEG   µV    -11084.10      -4.57      -0.51       3.55    4777.15
#   5  E6      EEG   µV    -11084.10      -3.55      -0.17       2.88    4028.57
#   6  E7      EEG   µV    -11084.10      -2.20      -0.17       1.86    3365.91
#   7  E8      EEG   µV    -11084.10     -11.33      -1.18       7.61    3217.41
#   8  E9      EEG   µV    -11084.10      -7.95      -0.85       6.26    8020.43
#   9  E10     EEG   µV    -11084.10      -5.92      -0.51       4.57    7473.46
# ...

# %%
new.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
